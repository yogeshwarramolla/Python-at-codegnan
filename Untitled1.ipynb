# %%
n=int(input())
for i in range(1,n+1):
    print(i)
# Out:
#  4
# 1
# 2
# 3
# 4

# %%
n=int(input())
for i in range(1,n+1):
    if i % 2==0:
        print(i)
    else:
        print(-1)
# Out:
#  10
# -1
# 2
# -1
# 4
# -1
# 6
# -1
# 8
# -1
# 10

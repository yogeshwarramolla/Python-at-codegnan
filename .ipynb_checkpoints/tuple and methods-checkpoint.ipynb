# %%
a=(10)
print(type(a))
b=(10,)
print(type(b))
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
a=(10,30,40,[70,80])
a[3].append(90) # here res= a[3].append(90) print (res) gives none becoz it modify in place
print(a)
# Out:
# (10, 30, 40, [70, 80, 90])

# %%
a=(20,60,70,90)
b=(10,24)
res= a+b
c=b*2
print(res)
print(c)
# Out:
# (20, 60, 70, 90, 10, 24)
# (10, 24, 10, 24)

# %%
a=(20,60,70,90)
res=min(a)
res1=max(a)
print(res)
print(res1)
print(len(a))
# Out:
# 20
# 90
# 4
